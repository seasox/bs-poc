# %%
import re

offsets = {}
with open("inject_4k.log", "r") as file:
    content = file.readlines()
    print(content)
    pattern_bait = re.compile(r"bait_before,bait_after: (\d+),(\d+)")
    pattern_some = re.compile(r'Some\("([^"]+)"\)')
    pattern_none = re.compile(r"None")
    pattern_pathname = re.compile(r'pathname: Some\("([^"]+)"\)')
    for line in content:
        match = pattern_bait.search(line)
        if match:
            key = (int(match.group(1)), int(match.group(2)))
            offsets[key] = []
        pathname_match = pattern_pathname.search(line)
        some_match = pattern_some.search(line)
        none_match = pattern_none.search(line)
        if pathname_match:
            pathname = pathname_match.group(1)
            offsets[key].append(pathname)
        elif some_match:
            offsets[key].append(some_match.group(1))
        elif none_match:
            offsets[key].append("Not reused")
        match = pattern_some.search(line)
offsets
# Out:
# ['bait_before,bait_after: 0,0\n', 'None\n', 'None\n', 'None\n', 'None\n', 'None\n', 'None\n', 'None\n', 'None\n', 'None\n', 'None\n', 'bait_before,bait_after: 0,1\n', 'Some(FlippyPage { maps_entry: MapsEntry { region: MemoryRegion { start: 108507003731968, end: 108507003736064 }, perms: READ, offset: 8192, dev: DeviceNumbers { major: 8, minor: 2 }, inode: 11575986, pathname: Some("/home/jb/rowhammer-jb/victim-stack/stack") }, region_offset: 0 })\n', 'Some(FlippyPage { maps_entry: MapsEntry { region: MemoryRegion { start: 103667438190592, end: 103667438194688 }, perms: READ, offset: 8192, dev: DeviceNumbers { major: 8, minor: 2 }, inode: 11575986, pathname: Some("/home/jb/rowhammer-jb/victim-stack/stack") }, region_offset: 0 })\n', 'Some(FlippyPage { maps_entry: MapsEntry { region: MemoryRegion { start: 124945344086016, end: 124945344094208 }, perms: READ | WRITE, offset: 0, dev: DeviceNumbers { major: 0, minor: 0 }, inode: 0, pathname: None }, region_offset: 0 })\n', 'Some(FlippyPage { maps_entry: MapsEntry { region: MemoryRegion { start: 98784631193600, end: 98784631197696 }, perms: READ, offset: 8192, dev: DeviceNumbers { major: 8, minor: 2 }, inode: 11575986, pathname: Some("/home/jb/rowhammer-jb/victim-stack/stack") }, region_offset: 0 })\n', 'Some(FlippyPage { maps_entry: MapsEntry { region: MemoryRegion { start: 106062491131904, end: 106062491136000 }, perms: READ, offset: 8192, dev: DeviceNumbers { major: 8, minor: 2 }, inode: 11575986, pathname: Some("/home/jb/rowhammer-jb/victim-stack/stack") }, region_offset: 0 })\n', 'Some(FlippyPage { maps_entry: MapsEntry { region: MemoryRegion { start: 98240853131264, end: 98240853135360 }, perms: READ, offset: 8192, dev: DeviceNumbers { major: 8, minor: 2 }, inode: 11575986, pathname: Some("/home/jb/rowhammer-jb/victim-stack/stack") }, region_offset: 0 })\n', 'Some(FlippyPage { maps_entry: MapsEntry { region: MemoryRegion { start: 101269583400960, end: 101269583405056 }, perms: READ, offset: 8192, dev: DeviceNumbers { major: 8, minor: 2 }, inode: 11575986, pathname: Some("/home/jb/rowhammer-jb/victim-stack/stack") }, region_offset: 0 })\n', 'Some(FlippyPage { maps_entry: MapsEntry { region: MemoryRegion { start: 96157037260800, end: 96157037264896 }, perms: READ, offset: 8192, dev: DeviceNumbers { major: 8, minor: 2 }, inode: 11575986, pathname: Some("/home/jb/rowhammer-jb/victim-stack/stack") }, region_offset: 0 })\n', 'Some(FlippyPage { maps_entry: MapsEntry { region: MemoryRegion { start: 140725188595712, end: 140725188730880 }, perms: READ | WRITE, offset: 0, dev: DeviceNumbers { major: 0, minor: 0 }, inode: 0, pathname: Some("[stack]") }, region_offset: 30 })\n', 'Some(FlippyPage { maps_entry: MapsEntry { region: MemoryRegion { start: 140723848392704, end: 140723848527872 }, perms: READ | WRITE, offset: 0, dev: DeviceNumbers { major: 0, minor: 0 }, inode: 0, pathname: Some("[stack]") }, region_offset: 30 })\n', 'bait_before,bait_after: 0,2\n', 'Some(FlippyPage { maps_entry: MapsEntry { region: MemoryRegion { start: 104268799012864, end: 104268799148032 }, perms: READ | WRITE, offset: 0, dev: DeviceNumbers { major: 0, minor: 0 }, inode: 0, pathname: Some("[heap]") }, region_offset: 1 })\n', 'Some(FlippyPage { maps_entry: MapsEntry { region: MemoryRegion { start: 96953470767104, end: 96953470902272 }, perms: READ | WRITE, offset: 0, dev: DeviceNumbers { major: 0, minor: 0 }, inode: 0, pathname: Some("[heap]") }, region_offset: 1 })\n', 'Some(FlippyPage { maps_entry: MapsEntry { region: MemoryRegion { start: 94837792886784, end: 94837793021952 }, perms: READ | WRITE, offset: 0, dev: DeviceNumbers { major: 0, minor: 0 }, inode: 0, pathname: Some("[heap]") }, region_offset: 1 })\n', 'None\n', 'None\n', 'None\n', 'None\n', 'None\n', 'None\n', 'None\n', 'bait_before,bait_after: 0,3\n', 'Some(FlippyPage { maps_entry: MapsEntry { region: MemoryRegion { start: 136126106210304, end: 136126106218496 }, perms: READ | WRITE, offset: 233472, dev: DeviceNumbers { major: 8, minor: 2 }, inod ...
# {(0, 0): ['Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused'],
#  (0, 1): ['/home/jb/rowhammer-jb/victim-stack/stack',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   'Not reused',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '[stack]',
#   '[stack]'],
#  (0, 2): ['[heap]',
#   '[heap]',
#   '[heap]',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused'],
#  (0, 3): ['/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '[stack]',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '[stack]'],
#  (0, 4): ['/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '[stack]',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/home/jb/rowhammer-jb/victim-stack/stack'],
#  (0, 5): ['[stack]',
#   '[stack]',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '[stack]',
#   '[stack]',
#   '[stack]',
#   '[stack]',
#   '[stack]',
#   '[stack]',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2'],
#  (0, 6): ['/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2'],
#  (0, 7): ['/home/jb/rowhammer-jb/victim-stack/stack',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/home/jb/rowhammer-jb/victim-stack/stack'],
#  (0, 8): ['/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '[heap]',
#   '[heap]',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '[heap]',
#   '[heap]',
#   '[heap]',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '[heap]',
#   '[heap]'],
#  (0, 9): ['Not reused',
#   '[heap]',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   'Not reused',
#   '[heap]',
#   'Not reused',
#   '[heap]'],
#  (0, 10): ['/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '[heap]',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '[heap]',
#   '[heap]',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2'],
#  (0, 11): ['/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2'],
#  (0, 12): ['Not reused',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   'Not reused',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   'Not reused'],
#  (0, 13): ['/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '[stack]',
#   '[stack]',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '[stack]',
#   'Not reused'],
#  (0, 14): ['[stack]',
#   'Not reused',
#   'Not reused',
#   '[stack]',
#   '[stack]',
#   '[stack]',
#   '[stack]',
#   '[stack]',
#   '[stack]',
#   'Not reused'],
#  (0, 15): ['/usr/lib/x86_64-linux-gnu/libc.so.6',
#   'Not reused',
#   'Not reused',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '[heap]',
#   '[heap]',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6'],
#  (0, 16): ['/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6'],
#  (0, 17): ['Not reused',
#   'Not reused',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6'],
#  (0, 18): ['Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused'],
#  (0, 19): ['/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6'],
#  (0, 20): ['Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused'],
#  (0, 21): ['Not reused',
#   '[stack]',
#   '[stack]',
#   '[stack]',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   '[stack]',
#   'Not reused',
#   '[stack]'],
#  (0, 22): ['/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   'Not reused',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   'Not reused',
#   'Not reused',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   'Not reused',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6'],
#  (0, 23): ['Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused'],
#  (0, 24): ['Not reused',
#   'Not reused',
#   'Not reused',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused'],
#  (0, 25): ['/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '[stack]',
#   '[stack]',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '[stack]',
#   'Not reused',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '[stack]',
#   '[stack]'],
#  (0, 26): ['[stack]',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '[stack]',
#   'Not reused',
#   'Not reused',
#   '[stack]',
#   'Not reused',
#   '[stack]',
#   '[stack]'],
#  (0, 27): ['/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '[stack]',
#   '[stack]',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '[stack]',
#   '[stack]',
#   '[stack]',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '[stack]'],
#  (0, 28): ['[stack]',
#   '[stack]',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '[stack]',
#   '[stack]',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '[stack]'],
#  (0, 29): ['Not reused',
#   '[stack]',
#   'Not reused',
#   '[stack]',
#   '[stack]',
#   '[stack]',
#   '[stack]',
#   'Not reused',
#   'Not reused',
#   '[stack]'],
#  (1, 0): ['Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused'],
#  (1, 1): ['Not reused',
#   '[stack]',
#   '[stack]',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   'Not reused',
#   'Not reused',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   'Not reused'],
#  (1, 2): ['[heap]',
#   '[heap]',
#   '[heap]',
#   'Not reused',
#   '[heap]',
#   '[heap]',
#   'Not reused',
#   '[heap]',
#   'Not reused',
#   'Not reused'],
#  (1, 3): ['/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2'],
#  (1, 4): ['/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '[stack]',
#   '[stack]',
#   '[stack]',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '[stack]',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2'],
#  (1, 5): ['[stack]',
#   '[stack]',
#   '[stack]',
#   '[stack]',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '[stack]',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '[stack]',
#   '[stack]',
#   '[stack]'],
#  (1, 6): ['/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '[stack]',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2'],
#  (1, 7): ['/home/jb/rowhammer-jb/victim-stack/stack',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/home/jb/rowhammer-jb/victim-stack/stack'],
#  (1, 8): ['[heap]',
#   'Not reused',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '[heap]',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '[heap]',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '[heap]',
#   '[heap]',
#   '[heap]'],
#  (1, 9): ['Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   '[heap]',
#   '[heap]',
#   'Not reused',
#   '[heap]'],
#  (1, 10): ['/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '[heap]',
#   '[heap]',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '[heap]',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '[heap]',
#   '[heap]',
#   '[heap]'],
#  (1, 11): ['/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2'],
#  (1, 12): ['/usr/lib/x86_64-linux-gnu/libc.so.6',
#   'Not reused',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   'Not reused',
#   'Not reused',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6'],
#  (1, 13): ['/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '[stack]',
#   'Not reused',
#   '[stack]',
#   'Not reused',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   'Not reused',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '[stack]',
#   '[stack]'],
#  (1, 14): ['[stack]',
#   '[stack]',
#   '[stack]',
#   '[stack]',
#   '[stack]',
#   'Not reused',
#   '[stack]',
#   '[stack]',
#   '[stack]',
#   '[stack]'],
#  (1, 15): ['Not reused',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '[stack]',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '[heap]',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   'Not reused',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   'Not reused'],
#  (1, 16): ['/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6'],
#  (1, 17): ['/usr/lib/x86_64-linux-gnu/libc.so.6',
#   'Not reused',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   'Not reused',
#   'Not reused',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   'Not reused',
#   'Not reused',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   'Not reused'],
#  (1, 18): ['Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused'],
#  (1, 19): ['Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   'Not reused',
#   'Not reused',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6'],
#  (1, 20): ['Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused'],
#  (1, 21): ['Not reused',
#   'Not reused',
#   '[stack]',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   '[stack]',
#   'Not reused',
#   'Not reused'],
#  (1, 22): ['Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   'Not reused'],
#  (1, 23): ['Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused'],
#  (1, 24): ['Not reused',
#   'Not reused',
#   'Not reused',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   'Not reused',
#   'Not reused',
#   '[stack]',
#   'Not reused',
#   'Not reused'],
#  (1, 25): ['[stack]',
#   '[stack]',
#   '[stack]',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   'Not reused',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   'Not reused',
#   '[stack]',
#   '[stack]'],
#  (1, 26): ['Not reused',
#   'Not reused',
#   'Not reused',
#   '[stack]',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '[stack]',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '[stack]',
#   'Not reused',
#   'Not reused'],
#  (1, 27): ['/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '[stack]',
#   '[stack]',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '[stack]',
#   '[stack]',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '[stack]',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '[stack]'],
#  (1, 28): ['/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '[stack]',
#   '[stack]',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '[stack]',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '[stack]'],
#  (1, 29): ['Not reused',
#   '[stack]',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   '[stack]',
#   '[stack]',
#   '[stack]',
#   'Not reused'],
#  (2, 0): ['Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused'],
#  (2, 1): ['[stack]',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   'Not reused',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   'Not reused'],
#  (2, 2): ['Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused'],
#  (2, 3): ['/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '[stack]',
#   '[stack]',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2'],
#  (2, 4): ['[stack]',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2'],
#  (2, 5): ['[stack]',
#   '[stack]',
#   '[stack]',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '[stack]',
#   '[stack]',
#   '[stack]',
#   '[stack]',
#   '[stack]',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2'],
#  (2, 6): ['/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/home/jb/rowhammer-jb/victim-stack/stack'],
#  (2, 7): ['/home/jb/rowhammer-jb/victim-stack/stack',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/home/jb/rowhammer-jb/victim-stack/stack'],
#  (2, 8): ['[heap]',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '[heap]',
#   '[heap]',
#   '[heap]',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '[heap]',
#   '[heap]',
#   '[heap]',
#   '[heap]'],
#  (2, 9): ['Not reused',
#   'Not reused',
#   'Not reused',
#   '[heap]',
#   'Not reused',
#   '[heap]',
#   '[heap]',
#   '[heap]',
#   'Not reused',
#   '[heap]'],
#  (2, 10): ['/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '[heap]',
#   '[heap]',
#   '[heap]',
#   '[heap]',
#   '[heap]',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '[heap]'],
#  (2, 11): ['/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6'],
#  (2, 12): ['/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   'Not reused',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   'Not reused',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   'Not reused',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6'],
#  (2, 13): ['/usr/lib/x86_64-linux-gnu/libc.so.6',
#   'Not reused',
#   'Not reused',
#   '[stack]',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '[stack]',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6'],
#  (2, 14): ['[stack]',
#   'Not reused',
#   '[stack]',
#   'Not reused',
#   '[stack]',
#   '[stack]',
#   '[stack]',
#   '[stack]',
#   'Not reused',
#   '[stack]'],
#  (2, 15): ['/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   'Not reused',
#   '[heap]',
#   '[heap]',
#   'Not reused',
#   'Not reused',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6'],
#  (2, 16): ['/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6'],
#  (2, 17): ['/usr/lib/x86_64-linux-gnu/libc.so.6',
#   'Not reused',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   'Not reused',
#   'Not reused',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   'Not reused',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6'],
#  (2, 18): ['Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused'],
#  (2, 19): ['Not reused',
#   'Not reused',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   'Not reused',
#   'Not reused'],
#  (2, 20): ['Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused'],
#  (2, 21): ['Not reused',
#   '[stack]',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   '[stack]',
#   'Not reused',
#   'Not reused'],
#  (2, 22): ['Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   '[stack]',
#   'Not reused',
#   'Not reused'],
#  (2, 23): ['Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused'],
#  (2, 24): ['Not reused',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   'Not reused',
#   '[stack]',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   'Not reused',
#   'Not reused'],
#  (2, 25): ['/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '[stack]',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6'],
#  (2, 26): ['Not reused',
#   '[stack]',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   'Not reused',
#   'Not reused'],
#  (2, 27): ['/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '[stack]',
#   '[stack]',
#   '[stack]',
#   '[stack]',
#   '[stack]',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6'],
#  (2, 28): ['/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '[stack]',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '[stack]',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6'],
#  (2, 29): ['Not reused',
#   '[stack]',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   '[stack]',
#   'Not reused',
#   '[stack]'],
#  (3, 0): ['Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused'],
#  (3, 1): ['[stack]',
#   '[stack]',
#   '[stack]',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/home/jb/rowhammer-jb/victim-stack/stack'],
#  (3, 2): ['Not reused',
#   'Not reused',
#   '[heap]',
#   'Not reused',
#   '[heap]',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   '[heap]',
#   'Not reused'],
#  (3, 3): ['/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2'],
#  (3, 4): ['/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '[stack]',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2'],
#  (3, 5): ['[stack]',
#   '[stack]',
#   '[stack]',
#   '[stack]',
#   '[stack]',
#   '[stack]',
#   '[stack]',
#   '[stack]',
#   '[stack]',
#   '[stack]'],
#  (3, 6): ['/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '[stack]',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2'],
#  (3, 7): ['/home/jb/rowhammer-jb/victim-stack/stack',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/home/jb/rowhammer-jb/victim-stack/stack'],
#  (3, 8): ['/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '[heap]',
#   '[heap]',
#   '[heap]',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '[heap]',
#   '[heap]',
#   '[heap]'],
#  (3, 9): ['Not reused',
#   '[heap]',
#   '[heap]',
#   'Not reused',
#   'Not reused',
#   '[heap]',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '[heap]',
#   '[heap]',
#   'Not reused'],
#  (3, 10): ['[heap]',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '[heap]',
#   '[heap]',
#   '[heap]',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '[heap]',
#   '[heap]',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2'],
#  (3, 11): ['/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6'],
#  (3, 12): ['/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   'Not reused',
#   'Not reused'],
#  (3, 13): ['Not reused',
#   'Not reused',
#   '[stack]',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   'Not reused',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '[stack]',
#   'Not reused',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6'],
#  (3, 14): ['[stack]',
#   '[stack]',
#   'Not reused',
#   '[stack]',
#   '[stack]',
#   '[stack]',
#   '[stack]',
#   '[stack]',
#   '[stack]',
#   '[stack]'],
#  (3, 15): ['Not reused',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '[heap]',
#   '[heap]',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   'Not reused'],
#  (3, 16): ['/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6'],
#  (3, 17): ['/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6'],
#  (3, 18): ['Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused'],
#  (3, 19): ['Not reused',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6'],
#  (3, 20): ['Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused'],
#  (3, 21): ['Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   '[stack]',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused'],
#  (3, 22): ['/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused'],
#  (3, 23): ['Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused'],
#  (3, 24): ['Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   '/home/jb/rowhammer-jb/victim-stack/stack'],
#  (3, 25): ['Not reused',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   'Not reused',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '[stack]',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   'Not reused'],
#  (3, 26): ['[stack]',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   '[stack]',
#   'Not reused',
#   '[stack]',
#   'Not reused',
#   '[stack]'],
#  (3, 27): ['[stack]',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '[stack]',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '[stack]',
#   '[stack]',
#   '[stack]',
#   '[stack]',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '[stack]'],
#  (3, 28): ['[stack]',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '[stack]',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '[stack]',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '[stack]',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6'],
#  (3, 29): ['Not reused',
#   '[stack]',
#   'Not reused',
#   '[stack]',
#   '[stack]',
#   '[stack]',
#   'Not reused',
#   '[stack]',
#   '[stack]',
#   '[stack]'],
#  (4, 0): ['Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   '[heap]'],
#  (4, 1): ['/home/jb/rowhammer-jb/victim-stack/stack',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '[stack]',
#   'Not reused',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   'Not reused',
#   'Not reused',
#   '[stack]',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/home/jb/rowhammer-jb/victim-stack/stack'],
#  (4, 2): ['Not reused',
#   '[heap]',
#   '[heap]',
#   '[heap]',
#   'Not reused',
#   'Not reused',
#   '[heap]',
#   '[heap]',
#   'Not reused',
#   '[heap]'],
#  (4, 3): ['/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '[stack]'],
#  (4, 4): ['[stack]',
#   '[stack]',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '[stack]',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2'],
#  (4, 5): ['[stack]',
#   '[stack]',
#   '[stack]',
#   '[stack]',
#   '[stack]',
#   '[stack]',
#   '[stack]',
#   '[stack]',
#   '[stack]',
#   '[stack]'],
#  (4, 6): ['/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '[stack]',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '[stack]',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2'],
#  (4, 7): ['/home/jb/rowhammer-jb/victim-stack/stack',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/home/jb/rowhammer-jb/victim-stack/stack'],
#  (4, 8): ['[heap]',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '[heap]',
#   '[heap]',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '[heap]',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '[heap]',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2'],
#  (4, 9): ['Not reused',
#   'Not reused',
#   '[heap]',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '[heap]',
#   '[heap]',
#   '[heap]',
#   'Not reused',
#   'Not reused',
#   '[heap]'],
#  (4, 10): ['/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '[heap]',
#   '[heap]',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '[heap]',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '[heap]'],
#  (4, 11): ['/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6'],
#  (4, 12): ['Not reused',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   'Not reused',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6'],
#  (4, 13): ['Not reused',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   'Not reused',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '[stack]',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '[stack]',
#   '[stack]',
#   'Not reused'],
#  (4, 14): ['[stack]',
#   '[stack]',
#   'Not reused',
#   '[stack]',
#   '[stack]',
#   '[stack]',
#   'Not reused',
#   '[stack]',
#   '[stack]',
#   '[stack]'],
#  (4, 15): ['/usr/lib/x86_64-linux-gnu/libc.so.6',
#   'Not reused',
#   '[heap]',
#   'Not reused',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   'Not reused',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '[heap]'],
#  (4, 16): ['/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6'],
#  (4, 17): ['/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   'Not reused',
#   'Not reused',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   'Not reused'],
#  (4, 18): ['Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused'],
#  (4, 19): ['Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused'],
#  (4, 20): ['Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused'],
#  (4, 21): ['Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   '[stack]',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused'],
#  (4, 22): ['/usr/lib/x86_64-linux-gnu/libc.so.6',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused'],
#  (4, 23): ['Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused'],
#  (4, 24): ['Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   '[stack]',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   'Not reused',
#   'Not reused',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   'Not reused'],
#  (4, 25): ['Not reused',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '[stack]',
#   'Not reused',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '[stack]',
#   'Not reused',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6'],
#  (4, 26): ['[stack]',
#   '[stack]',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused'],
#  (4, 27): ['/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '[stack]',
#   '[stack]',
#   '[stack]',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6'],
#  (4, 28): ['[stack]',
#   '[stack]',
#   '[stack]',
#   '[stack]',
#   '[stack]',
#   '[stack]',
#   '[stack]',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '[stack]',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6'],
#  (4, 29): ['Not reused',
#   'Not reused',
#   '[stack]',
#   '[stack]',
#   'Not reused',
#   'Not reused',
#   '[stack]',
#   '[stack]',
#   '[stack]',
#   'Not reused'],
#  (5, 0): ['Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused'],
#  (5, 1): ['/home/jb/rowhammer-jb/victim-stack/stack',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   'Not reused',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   'Not reused',
#   'Not reused',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/home/jb/rowhammer-jb/victim-stack/stack'],
#  (5, 2): ['[heap]',
#   'Not reused',
#   'Not reused',
#   '[heap]',
#   'Not reused',
#   'Not reused',
#   '[heap]',
#   '[heap]',
#   '[heap]',
#   'Not reused'],
#  (5, 3): ['/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '[stack]',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2'],
#  (5, 4): ['/home/jb/rowhammer-jb/victim-stack/stack',
#   '[stack]',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2'],
#  (5, 5): ['[stack]',
#   '[stack]',
#   '[stack]',
#   '[stack]',
#   '[stack]',
#   '[stack]',
#   '[stack]',
#   '[stack]',
#   '[stack]',
#   '[stack]'],
#  (5, 6): ['/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
# ...
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2'],
#  (28, 4): ['/home/jb/rowhammer-jb/victim-stack/stack',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '[stack]',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '[stack]',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2'],
#  (28, 5): ['[stack]',
#   '[stack]',
#   '[stack]',
#   '[stack]',
#   '[stack]',
#   '[stack]',
#   '[stack]',
#   '[stack]',
#   '[stack]',
#   '[stack]'],
#  (28, 6): ['/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2'],
#  (28, 7): ['/home/jb/rowhammer-jb/victim-stack/stack',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/home/jb/rowhammer-jb/victim-stack/stack'],
#  (28, 8): ['/home/jb/rowhammer-jb/victim-stack/stack',
#   '[heap]',
#   '[heap]',
#   '[heap]',
#   '[heap]',
#   '[heap]',
#   '[heap]',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '[heap]',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2'],
#  (28, 9): ['Not reused',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '[heap]',
#   'Not reused',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '[heap]',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused'],
#  (28, 10): ['/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '[heap]',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '[heap]',
#   '[heap]',
#   '[heap]',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '[heap]',
#   '[heap]'],
#  (28, 11): ['/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6'],
#  (28, 12): ['Not reused',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   'Not reused',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6'],
#  (28, 13): ['[stack]',
#   '[stack]',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '[stack]',
#   'Not reused',
#   'Not reused',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '[stack]'],
#  (28, 14): ['[stack]',
#   '[stack]',
#   '[stack]',
#   '[stack]',
#   '[stack]',
#   '[stack]',
#   '[stack]',
#   'Not reused',
#   '[stack]',
#   '[stack]'],
#  (28, 15): ['/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   'Not reused',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '[heap]',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6'],
#  (28, 16): ['/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6'],
#  (28, 17): ['/usr/lib/x86_64-linux-gnu/libc.so.6',
#   'Not reused',
#   'Not reused',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   'Not reused',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   'Not reused',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6'],
#  (28, 18): ['Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused'],
#  (28, 19): ['Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   'Not reused'],
#  (28, 20): ['Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused'],
#  (28, 21): ['Not reused',
#   'Not reused',
#   'Not reused',
#   '[stack]',
#   '[stack]',
#   'Not reused',
#   '[stack]',
#   'Not reused',
#   'Not reused',
#   'Not reused'],
#  (28, 22): ['/usr/lib/x86_64-linux-gnu/libc.so.6',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6'],
#  (28, 23): ['Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused'],
#  (28, 24): ['/home/jb/rowhammer-jb/victim-stack/stack',
#   'Not reused',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   'Not reused',
#   'Not reused',
#   'Not reused'],
#  (28, 25): ['[stack]',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   'Not reused',
#   'Not reused',
#   '[stack]',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused'],
#  (28, 26): ['[stack]',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   'Not reused',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   'Not reused',
#   'Not reused',
#   '[stack]',
#   'Not reused',
#   '[stack]',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6'],
#  (28, 27): ['/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '[stack]',
#   '[stack]',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '[stack]',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6'],
#  (28, 28): ['/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '[stack]',
#   '[stack]',
#   '[stack]',
#   '[stack]',
#   '[stack]',
#   '[stack]',
#   '[stack]',
#   '[stack]',
#   '[stack]'],
#  (28, 29): ['[stack]',
#   '[stack]',
#   '[stack]',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused'],
#  (29, 0): ['Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused'],
#  (29, 1): ['/home/jb/rowhammer-jb/victim-stack/stack',
#   '[stack]',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   'Not reused',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   'Not reused',
#   '[stack]',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2'],
#  (29, 2): ['[heap]',
#   '[heap]',
#   '[heap]',
#   'Not reused',
#   '[heap]',
#   'Not reused',
#   'Not reused',
#   '[heap]',
#   'Not reused',
#   '[heap]'],
#  (29, 3): ['/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2'],
#  (29, 4): ['/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2'],
#  (29, 5): ['[stack]',
#   '[stack]',
#   '[stack]',
#   '[stack]',
#   '[stack]',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '[stack]',
#   '[stack]',
#   '[stack]',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2'],
#  (29, 6): ['/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2'],
#  (29, 7): ['/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/home/jb/rowhammer-jb/victim-stack/stack'],
#  (29, 8): ['/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '[heap]',
#   '[heap]',
#   '[heap]',
#   '[heap]',
#   '[heap]',
#   '[heap]',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   'Not reused'],
#  (29, 9): ['/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '[heap]',
#   'Not reused',
#   '[heap]',
#   '[heap]',
#   'Not reused',
#   '[heap]',
#   '[heap]',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   'Not reused'],
#  (29, 10): ['[heap]',
#   '[stack]',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '[heap]',
#   '[heap]',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2'],
#  (29, 11): ['/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2'],
#  (29, 12): ['Not reused',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   'Not reused',
#   'Not reused',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   'Not reused',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6'],
#  (29, 13): ['/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   'Not reused',
#   '[stack]',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '[stack]',
#   '[stack]',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6'],
#  (29, 14): ['[stack]',
#   '[stack]',
#   '[stack]',
#   '[stack]',
#   'Not reused',
#   '[stack]',
#   'Not reused',
#   '[stack]',
#   'Not reused',
#   'Not reused'],
#  (29, 15): ['[heap]',
#   'Not reused',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '[heap]',
#   'Not reused',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '[heap]',
#   'Not reused',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6'],
#  (29, 16): ['/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6'],
#  (29, 17): ['/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   'Not reused',
#   'Not reused',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6'],
#  (29, 18): ['Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused'],
#  (29, 19): ['/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   'Not reused',
#   'Not reused'],
#  (29, 20): ['Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused'],
#  (29, 21): ['[stack]',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   '[stack]',
#   'Not reused',
#   'Not reused'],
#  (29, 22): ['Not reused',
#   'Not reused',
#   'Not reused',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   'Not reused',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   'Not reused'],
#  (29, 23): ['Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused'],
#  (29, 24): ['/home/jb/rowhammer-jb/victim-stack/stack',
#   '/home/jb/rowhammer-jb/victim-stack/stack',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   '[stack]',
#   'Not reused',
#   'Not reused',
#   'Not reused'],
#  (29, 25): ['Not reused',
#   'Not reused',
#   '[stack]',
#   'Not reused',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '[stack]',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   'Not reused',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6'],
#  (29, 26): ['Not reused',
#   'Not reused',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '[stack]',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   '[stack]',
#   'Not reused'],
#  (29, 27): ['/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '[stack]',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '[stack]',
#   '[stack]',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '[stack]'],
#  (29, 28): ['[stack]',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '[stack]',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '[stack]',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '[stack]',
#   '/usr/lib/x86_64-linux-gnu/libc.so.6',
#   '[stack]'],
#  (29, 29): ['[stack]',
#   '[stack]',
#   'Not reused',
#   '[stack]',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   'Not reused',
#   '[stack]',
#   'Not reused']}

# %%
data = offsets

from collections import Counter
max_key = max(data, key=lambda k: Counter(data[k])['[stack]'])

print(max_key)
# Out:
# (3, 5)

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Example data
data = offsets

# Convert data into a suitable format
# Create a set of unique values
keys = data.keys()
dim_x = max(key[0] for key in keys) + 1
dim_y = max(key[1] for key in keys) + 1
unique_values = sorted(set(value for values in data.values() for value in values))

# Create an empty matrix for heatmap
heatmap_data = np.zeros((30, 30, len(unique_values)))

# Populate the heatmap data
for (x, y), values in data.items():
    if x >= 30 or y >= 30:
        continue
    for value in values:
        idx = unique_values.index(value)
        heatmap_data[x, y, idx] += 1

# Plot heatmaps for each unique value
for i, value in enumerate(unique_values):
    plt.figure(figsize=(8, 8))
    sns.heatmap(heatmap_data[:, :, i], cmap='Blues', 
                xticklabels='auto', yticklabels='auto', 
                cbar_kws={'label': 'Probability'})
    plt.title(f'Heatmap for value: {value}')
    plt.xlabel('Bait pages after')
    plt.ylabel('Bait pages before')
    plt.show()

# %%
import matplotlib.pyplot as plt
from collections import Counter

# Sample data (use the full data in your case)
data = offsets

# Get all unique values across all keys and convert to a sorted list
unique_values = sorted(set(value for values in data.values() for value in values))

if False:
    # Plot for each key
    for key, values in data.items():
        values = data[key]
        # Count occurrences of each unique value for the current key
        value_counts = Counter(values)
        
        if value_counts.get('None') == len(values):
            continue

        # Extract counts in the same order as unique_values
        counts = [value_counts.get(value, 0) for value in unique_values]
        values = [v for v in unique_values if counts[unique_values.index(v)] != 0]
        counts = [c for c in counts if c != 0]
        
        # Plotting
        plt.figure(figsize=(8, 4))
        plt.bar(values, counts, color='skyblue')
        
        # Labels and title
        plt.xlabel("Memory Region")
        plt.ylabel("Count")
        plt.title(f"Page injected into memory region for {key} (before/after) bait pages")
        plt.xticks(rotation=45)

        plt.tight_layout()
        plt.savefig(f"plots/plot_{key}.png")
        plt.close()
